# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        
        for f in files :
            all_files.append(os.path.abspath(f))
#             print(all_files)
            
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
song_files = get_files('data/song_data')

# %%
filepath = song_files[0]

# %%
print(filepath)
# Out:
# /home/workspace/data/song_data/A/B/C/TRABCRU128F423F449.json

# %%
df = pd.read_json(filepath,lines=True)
df.head()
# Out:
#             artist_id  artist_latitude artist_location  artist_longitude  \
# 0  AR8IEZO1187B99055E              NaN                               NaN
#
#     artist_name   duration  num_songs             song_id          title  year
# 0  Marc Shaiman  149.86404          1  SOINLJW12A8C13314C  City Slickers  2008

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
song_data_values = df[['song_id','title','artist_id','year','duration']].values
first_record = song_data_values[0]
song_data = first_record.tolist()
song_data
# Out:
# ['SOINLJW12A8C13314C', 'City Slickers', 'AR8IEZO1187B99055E', 2008, 149.86404]

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
cur.execute(song_table_insert, song_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
artist_data_values = df[['artist_id','artist_name','artist_location','artist_latitude','artist_longitude']].values
print(artist_data_values)
# Out:
# [['AR8IEZO1187B99055E' 'Marc Shaiman' '' nan nan]]

# %%
artist_data_values = df[['artist_id','artist_name','artist_location','artist_latitude','artist_longitude']].values
first_record = artist_data_values[0]
artist_data = first_record.tolist()
artist_data
# Out:
# ['AR8IEZO1187B99055E', 'Marc Shaiman', '', nan, nan]

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
cur.execute(artist_table_insert, artist_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files('data/log_data')

# %%
filepath = log_files[0]

# %%
print(filepath)
# Out:
# /home/workspace/data/log_data/2018/11/2018-11-29-events.json

# %%
df = pd.read_json(filepath, lines=True)
df.head()
# Out:
#               artist       auth firstName gender  itemInSession lastName  \
# 0  Sydney Youngblood  Logged In     Jacob      M             53    Klein
# 1         Gang Starr  Logged In     Layla      F             88  Griffin
# 2              3OH!3  Logged In     Layla      F             89  Griffin
# 3        RÃÂ¶yksopp  Logged In     Jacob      M             54    Klein
# 4         Kajagoogoo  Logged In     Layla      F             90  Griffin
#
#       length level                             location method      page  \
# 0  238.07955  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 1  151.92771  paid         Lake Havasu City-Kingman, AZ    PUT  NextSong
# 2  192.52200  paid         Lake Havasu City-Kingman, AZ    PUT  NextSong
# 3  369.81506  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 4  223.55546  paid         Lake Havasu City-Kingman, AZ    PUT  NextSong
#
#    registration  sessionId                                         song  \
# 0  1.540558e+12        954                            Ain't No Sunshine
# 1  1.541057e+12        984                   My Advice 2 You (Explicit)
# 2  1.541057e+12        984  My First Kiss (Feat. Ke$ha) [Album Version]
# 3  1.540558e+12        954                       The Girl and The Robot
# 4  1.541057e+12        984                                      Too Shy
#
#    status             ts                                          userAgent  \
# 0     200  1543449657796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 1     200  1543449690796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 2     200  1543449841796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 3     200  1543449895796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 4     200  1543450033796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
#
#   userId
# 0     73
# 1     24
# 2     24
# 3     73
# 4     24

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
df = df[df['page'] == 'NextSong']
df.head()
# Out:
#               artist       auth firstName gender  itemInSession lastName  \
# 0  Sydney Youngblood  Logged In     Jacob      M             53    Klein
# 1         Gang Starr  Logged In     Layla      F             88  Griffin
# 2              3OH!3  Logged In     Layla      F             89  Griffin
# 3        RÃÂ¶yksopp  Logged In     Jacob      M             54    Klein
# 4         Kajagoogoo  Logged In     Layla      F             90  Griffin
#
#       length level                             location method      page  \
# 0  238.07955  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 1  151.92771  paid         Lake Havasu City-Kingman, AZ    PUT  NextSong
# 2  192.52200  paid         Lake Havasu City-Kingman, AZ    PUT  NextSong
# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():
    print(i)
    print(row)
    
    cur.execute(time_table_insert, list(row))
    conn.commit()
# Out:
# 0
# timestamp     2018-11-29 00:00:57.796000
# hour                                   0
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 0, dtype: object
# 1
# timestamp     2018-11-29 00:01:30.796000
# hour                                   0
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 1, dtype: object
# 2
# timestamp     2018-11-29 00:04:01.796000
# hour                                   0
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 2, dtype: object
# 3
# timestamp     2018-11-29 00:04:55.796000
# hour                                   0
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 3, dtype: object
# 4
# timestamp     2018-11-29 00:07:13.796000
# hour                                   0
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 4, dtype: object
# 5
# timestamp     2018-11-29 00:10:56.796000
# hour                                   0
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 5, dtype: object
# 6
# timestamp     2018-11-29 00:11:04.796000
# hour                                   0
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 6, dtype: object
# 7
# timestamp     2018-11-29 00:14:10.796000
# hour                                   0
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 7, dtype: object
# 8
# timestamp     2018-11-29 00:16:02.796000
# hour                                   0
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 8, dtype: object
# 9
# timestamp     2018-11-29 00:18:11.796000
# hour                                   0
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 9, dtype: object
# 10
# timestamp     2018-11-29 00:22:13.796000
# hour                                   0
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 10, dtype: object
# 11
# timestamp     2018-11-29 00:26:15.796000
# hour                                   0
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 11, dtype: object
# 12
# timestamp     2018-11-29 00:30:53.796000
# hour                                   0
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 12, dtype: object
# 13
# timestamp     2018-11-29 00:35:07.796000
# hour                                   0
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 13, dtype: object
# 14
# timestamp     2018-11-29 00:40:14.796000
# hour                                   0
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 14, dtype: object
# 15
# timestamp     2018-11-29 00:44:13.796000
# hour                                   0
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 15, dtype: object
# 16
# timestamp     2018-11-29 00:46:34.796000
# hour                                   0
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 16, dtype: object
# 17
# timestamp     2018-11-29 00:49:48.796000
# hour                                   0
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 17, dtype: object
# 18
# timestamp     2018-11-29 00:57:10.796000
# hour                                   0
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 18, dtype: object
# 19
# timestamp     2018-11-29 01:02:12.796000
# hour                                   1
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 19, dtype: object
# 20
# timestamp     2018-11-29 01:06:36.796000
# hour                                   1
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 20, dtype: object
# 21
# timestamp     2018-11-29 01:09:23.796000
# hour                                   1
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 21, dtype: object
# 22
# timestamp     2018-11-29 01:09:58.796000
# hour                                   1
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 22, dtype: object
# 23
# timestamp     2018-11-29 01:13:57.796000
# hour                                   1
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 23, dtype: object
# 24
# timestamp     2018-11-29 01:17:34.796000
# hour                                   1
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 24, dtype: object
# 25
# timestamp     2018-11-29 01:22:13.796000
# hour                                   1
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 25, dtype: object
# 26
# timestamp     2018-11-29 01:26:18.796000
# hour                                   1
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 26, dtype: object
# 27
# timestamp     2018-11-29 01:31:13.796000
# hour                                   1
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 27, dtype: object
# 28
# timestamp     2018-11-29 01:33:38.796000
# hour                                   1
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 28, dtype: object
# 29
# timestamp     2018-11-29 01:38:30.796000
# hour                                   1
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 29, dtype: object
# 30
# timestamp     2018-11-29 01:42:27.796000
# hour                                   1
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 30, dtype: object
# 31
# timestamp     2018-11-29 01:46:50.796000
# hour                                   1
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 31, dtype: object
# 32
# timestamp     2018-11-29 01:52:26.796000
# hour                                   1
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 32, dtype: object
# 33
# timestamp     2018-11-29 01:55:17.796000
# hour                                   1
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 33, dtype: object
# 34
# timestamp     2018-11-29 02:24:31.796000
# hour                                   2
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 34, dtype: object
# 35
# timestamp     2018-11-29 02:28:05.796000
# hour                                   2
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 35, dtype: object
# 36
# timestamp     2018-11-29 02:31:11.796000
# hour                                   2
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 36, dtype: object
# 37
# timestamp     2018-11-29 02:36:13.796000
# hour                                   2
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 37, dtype: object
# 38
# timestamp     2018-11-29 02:40:10.796000
# hour                                   2
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 38, dtype: object
# 39
# timestamp     2018-11-29 02:57:57.796000
# hour                                   2
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 39, dtype: object
# 40
# timestamp     2018-11-29 03:00:42.796000
# hour                                   3
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 40, dtype: object
# 41
# timestamp     2018-11-29 03:07:15.796000
# hour                                   3
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 41, dtype: object
# 42
# timestamp     2018-11-29 04:27:16.796000
# hour                                   4
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 42, dtype: object
# 43
# timestamp     2018-11-29 04:31:53.796000
# hour                                   4
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 43, dtype: object
# 44
# timestamp     2018-11-29 04:55:55.796000
# hour                                   4
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 44, dtype: object
# 45
# timestamp     2018-11-29 05:00:08.796000
# hour                                   5
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 45, dtype: object
# 46
# timestamp     2018-11-29 08:18:42.796000
# hour                                   8
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 46, dtype: object
# 47
# timestamp     2018-11-29 08:23:09.796000
# hour                                   8
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 47, dtype: object
# 48
# timestamp     2018-11-29 10:59:27.796000
# hour                                  10
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 48, dtype: object
# 49
# timestamp     2018-11-29 11:03:12.796000
# hour                                  11
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 49, dtype: object
# 50
# timestamp     2018-11-29 11:03:31.796000
# hour                                  11
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 50, dtype: object
# 51
# timestamp     2018-11-29 11:07:19.796000
# hour                                  11
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 51, dtype: object
# 52
# timestamp     2018-11-29 11:10:57.796000
# hour                                  11
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 52, dtype: object
# 53
# timestamp     2018-11-29 12:21:07.796000
# hour                                  12
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 53, dtype: object
# 54
# timestamp     2018-11-29 13:14:11.796000
# hour                                  13
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 54, dtype: object
# 55
# timestamp     2018-11-29 13:58:27.796000
# hour                                  13
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 55, dtype: object
# 56
# timestamp     2018-11-29 14:01:21.796000
# hour                                  14
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 56, dtype: object
# 57
# timestamp     2018-11-29 14:05:13.796000
# hour                                  14
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 57, dtype: object
# 58
# timestamp     2018-11-29 14:10:08.796000
# hour                                  14
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 58, dtype: object
# 59
# timestamp     2018-11-29 14:14:04.796000
# hour                                  14
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 59, dtype: object
# 60
# timestamp     2018-11-29 14:17:50.796000
# hour                                  14
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 60, dtype: object
# 61
# timestamp     2018-11-29 14:22:14.796000
# hour                                  14
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 61, dtype: object
# 62
# timestamp     2018-11-29 14:26:23.796000
# hour                                  14
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 62, dtype: object
# 63
# timestamp     2018-11-29 14:32:31.796000
# hour                                  14
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 63, dtype: object
# 64
# timestamp     2018-11-29 14:35:44.796000
# hour                                  14
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 64, dtype: object
# 65
# timestamp     2018-11-29 14:40:36.796000
# hour                                  14
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 65, dtype: object
# 66
# timestamp     2018-11-29 14:43:29.796000
# hour                                  14
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 66, dtype: object
# 67
# timestamp     2018-11-29 14:47:47.796000
# hour                                  14
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 67, dtype: object
# 68
# timestamp     2018-11-29 14:51:12.796000
# hour                                  14
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 68, dtype: object
# 69
# timestamp     2018-11-29 14:55:45.796000
# hour                                  14
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 69, dtype: object
# 70
# timestamp     2018-11-29 14:57:52.796000
# hour                                  14
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 70, dtype: object
# 71
# timestamp     2018-11-29 15:02:51.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 71, dtype: object
# 72
# timestamp     2018-11-29 15:05:49.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 72, dtype: object
# 73
# timestamp     2018-11-29 15:06:52.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 73, dtype: object
# 74
# timestamp     2018-11-29 15:09:44.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 74, dtype: object
# 75
# timestamp     2018-11-29 15:11:08.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 75, dtype: object
# 76
# timestamp     2018-11-29 15:11:35.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 76, dtype: object
# 77
# timestamp     2018-11-29 15:11:47.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 77, dtype: object
# 78
# timestamp     2018-11-29 15:12:48.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 78, dtype: object
# 79
# timestamp     2018-11-29 15:14:34.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 79, dtype: object
# 80
# timestamp     2018-11-29 15:15:28.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 80, dtype: object
# 81
# timestamp     2018-11-29 15:15:36.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 81, dtype: object
# 82
# timestamp     2018-11-29 15:16:13.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 82, dtype: object
# 83
# timestamp     2018-11-29 15:18:58.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 83, dtype: object
# 84
# timestamp     2018-11-29 15:19:32.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 84, dtype: object
# 85
# timestamp     2018-11-29 15:20:30.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 85, dtype: object
# 86
# timestamp     2018-11-29 15:20:39.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 86, dtype: object
# 87
# timestamp     2018-11-29 15:22:38.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 87, dtype: object
# 88
# timestamp     2018-11-29 15:24:15.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 88, dtype: object
# 89
# timestamp     2018-11-29 15:26:40.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 89, dtype: object
# 90
# timestamp     2018-11-29 15:27:01.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 90, dtype: object
# 91
# timestamp     2018-11-29 15:27:37.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 91, dtype: object
# 92
# timestamp     2018-11-29 15:29:41.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 92, dtype: object
# 93
# timestamp     2018-11-29 15:30:01.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 93, dtype: object
# 94
# timestamp     2018-11-29 15:30:57.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 94, dtype: object
# 95
# timestamp     2018-11-29 15:33:38.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 95, dtype: object
# 96
# timestamp     2018-11-29 15:34:16.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 96, dtype: object
# 97
# timestamp     2018-11-29 15:36:32.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 97, dtype: object
# 98
# timestamp     2018-11-29 15:37:16.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 98, dtype: object
# 99
# timestamp     2018-11-29 15:39:39.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 99, dtype: object
# 100
# timestamp     2018-11-29 15:41:17.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 100, dtype: object
# 101
# timestamp     2018-11-29 15:41:57.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 101, dtype: object
# 102
# timestamp     2018-11-29 15:45:38.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 102, dtype: object
# 103
# timestamp     2018-11-29 15:45:41.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 103, dtype: object
# 104
# timestamp     2018-11-29 15:49:16.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 104, dtype: object
# 105
# timestamp     2018-11-29 15:49:38.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 105, dtype: object
# 106
# timestamp     2018-11-29 15:53:39.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 106, dtype: object
# 107
# timestamp     2018-11-29 15:54:12.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 107, dtype: object
# 108
# timestamp     2018-11-29 15:57:35.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 108, dtype: object
# 109
# timestamp     2018-11-29 15:57:55.796000
# hour                                  15
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 109, dtype: object
# 110
# timestamp     2018-11-29 16:00:01.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 110, dtype: object
# 111
# timestamp     2018-11-29 16:00:53.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 111, dtype: object
# 112
# timestamp     2018-11-29 16:04:06.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 112, dtype: object
# 113
# timestamp     2018-11-29 16:05:40.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 113, dtype: object
# 114
# timestamp     2018-11-29 16:07:07.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 114, dtype: object
# 115
# timestamp     2018-11-29 16:09:11.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 115, dtype: object
# 116
# timestamp     2018-11-29 16:09:24.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 116, dtype: object
# 117
# timestamp     2018-11-29 16:11:29.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 117, dtype: object
# 118
# timestamp     2018-11-29 16:13:23.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 118, dtype: object
# 119
# timestamp     2018-11-29 16:15:34.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 119, dtype: object
# 120
# timestamp     2018-11-29 16:18:25.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 120, dtype: object
# 121
# timestamp     2018-11-29 16:19:30.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 121, dtype: object
# 122
# timestamp     2018-11-29 16:22:24.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 122, dtype: object
# 123
# timestamp     2018-11-29 16:23:27.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 123, dtype: object
# 124
# timestamp     2018-11-29 16:26:21.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 124, dtype: object
# 125
# timestamp     2018-11-29 16:28:12.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 125, dtype: object
# 126
# timestamp     2018-11-29 16:30:05.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 126, dtype: object
# 127
# timestamp     2018-11-29 16:31:19.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 127, dtype: object
# 128
# timestamp     2018-11-29 16:34:03.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 128, dtype: object
# 129
# timestamp     2018-11-29 16:36:45.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 129, dtype: object
# 130
# timestamp     2018-11-29 16:38:29.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 130, dtype: object
# 131
# timestamp     2018-11-29 16:40:32.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 131, dtype: object
# 132
# timestamp     2018-11-29 16:41:33.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 132, dtype: object
# 133
# timestamp     2018-11-29 16:41:37.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 133, dtype: object
# 134
# timestamp     2018-11-29 16:44:39.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 134, dtype: object
# 135
# timestamp     2018-11-29 16:45:38.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 135, dtype: object
# 136
# timestamp     2018-11-29 16:47:38.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 136, dtype: object
# 137
# timestamp     2018-11-29 16:47:42.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 137, dtype: object
# 138
# timestamp     2018-11-29 16:49:25.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 138, dtype: object
# 139
# timestamp     2018-11-29 16:50:16.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 139, dtype: object
# 140
# timestamp     2018-11-29 16:54:22.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 140, dtype: object
# 141
# timestamp     2018-11-29 16:54:27.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 141, dtype: object
# 142
# timestamp     2018-11-29 16:54:41.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 142, dtype: object
# 143
# timestamp     2018-11-29 16:55:14.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 143, dtype: object
# 144
# timestamp     2018-11-29 16:58:01.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 144, dtype: object
# 145
# timestamp     2018-11-29 16:58:03.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 145, dtype: object
# 146
# timestamp     2018-11-29 16:58:11.796000
# hour                                  16
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 146, dtype: object
# 147
# timestamp     2018-11-29 17:01:21.796000
# hour                                  17
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 147, dtype: object
# 148
# timestamp     2018-11-29 17:01:34.796000
# hour                                  17
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 148, dtype: object
# 149
# timestamp     2018-11-29 17:01:41.796000
# hour                                  17
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 149, dtype: object
# 150
# timestamp     2018-11-29 17:01:49.796000
# hour                                  17
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 150, dtype: object
# 151
# timestamp     2018-11-29 17:05:10.796000
# hour                                  17
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 151, dtype: object
# 152
# timestamp     2018-11-29 17:05:20.796000
# hour                                  17
# day                                   29
# weekofyear                            48
# ...
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 268, dtype: object
# 269
# timestamp     2018-11-29 21:00:03.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 269, dtype: object
# 270
# timestamp     2018-11-29 21:01:07.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 270, dtype: object
# 271
# timestamp     2018-11-29 21:03:20.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 271, dtype: object
# 272
# timestamp     2018-11-29 21:06:03.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 272, dtype: object
# 273
# timestamp     2018-11-29 21:06:35.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 273, dtype: object
# 274
# timestamp     2018-11-29 21:09:20.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 274, dtype: object
# 275
# timestamp     2018-11-29 21:12:56.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 275, dtype: object
# 276
# timestamp     2018-11-29 21:14:16.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 276, dtype: object
# 277
# timestamp     2018-11-29 21:14:49.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 277, dtype: object
# 278
# timestamp     2018-11-29 21:16:53.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 278, dtype: object
# 279
# timestamp     2018-11-29 21:17:30.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 279, dtype: object
# 280
# timestamp     2018-11-29 21:19:18.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 280, dtype: object
# 281
# timestamp     2018-11-29 21:20:57.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 281, dtype: object
# 282
# timestamp     2018-11-29 21:21:47.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 282, dtype: object
# 283
# timestamp     2018-11-29 21:22:18.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 283, dtype: object
# 284
# timestamp     2018-11-29 21:24:03.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 284, dtype: object
# 285
# timestamp     2018-11-29 21:24:35.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 285, dtype: object
# 286
# timestamp     2018-11-29 21:27:00.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 286, dtype: object
# 287
# timestamp     2018-11-29 21:27:48.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 287, dtype: object
# 288
# timestamp     2018-11-29 21:27:50.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 288, dtype: object
# 289
# timestamp     2018-11-29 21:30:47.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 289, dtype: object
# 290
# timestamp     2018-11-29 21:31:34.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 290, dtype: object
# 291
# timestamp     2018-11-29 21:34:25.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 291, dtype: object
# 292
# timestamp     2018-11-29 21:34:28.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 292, dtype: object
# 293
# timestamp     2018-11-29 21:38:08.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 293, dtype: object
# 294
# timestamp     2018-11-29 21:42:10.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 294, dtype: object
# 295
# timestamp     2018-11-29 21:46:49.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 295, dtype: object
# 296
# timestamp     2018-11-29 21:52:57.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 296, dtype: object
# 297
# timestamp     2018-11-29 21:57:16.796000
# hour                                  21
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 297, dtype: object
# 298
# timestamp     2018-11-29 22:00:31.796000
# hour                                  22
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 298, dtype: object
# 299
# timestamp     2018-11-29 22:06:36.796000
# hour                                  22
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 299, dtype: object
# 300
# timestamp     2018-11-29 22:09:57.796000
# hour                                  22
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 300, dtype: object
# 301
# timestamp     2018-11-29 22:10:17.796000
# hour                                  22
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 301, dtype: object
# 302
# timestamp     2018-11-29 22:13:15.796000
# hour                                  22
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 302, dtype: object
# 303
# timestamp     2018-11-29 22:13:38.796000
# hour                                  22
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 303, dtype: object
# 304
# timestamp     2018-11-29 22:17:38.796000
# hour                                  22
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 304, dtype: object
# 305
# timestamp     2018-11-29 22:21:31.796000
# hour                                  22
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 305, dtype: object
# 306
# timestamp     2018-11-29 22:27:31.796000
# hour                                  22
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 306, dtype: object
# 307
# timestamp     2018-11-29 22:32:49.796000
# hour                                  22
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 307, dtype: object
# 308
# timestamp     2018-11-29 22:35:44.796000
# hour                                  22
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 308, dtype: object
# 309
# timestamp     2018-11-29 22:39:38.796000
# hour                                  22
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 309, dtype: object
# 310
# timestamp     2018-11-29 22:42:52.796000
# hour                                  22
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 310, dtype: object
# 311
# timestamp     2018-11-29 22:46:23.796000
# hour                                  22
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 311, dtype: object
# 312
# timestamp     2018-11-29 22:50:27.796000
# hour                                  22
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 312, dtype: object
# 313
# timestamp     2018-11-29 22:51:18.796000
# hour                                  22
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 313, dtype: object
# 314
# timestamp     2018-11-29 22:53:32.796000
# hour                                  22
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 314, dtype: object
# 315
# timestamp     2018-11-29 22:57:22.796000
# hour                                  22
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 315, dtype: object
# 316
# timestamp     2018-11-29 23:02:05.796000
# hour                                  23
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 316, dtype: object
# 317
# timestamp     2018-11-29 23:05:13.796000
# hour                                  23
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 317, dtype: object
# 318
# timestamp     2018-11-29 23:18:35.796000
# hour                                  23
# day                                   29
# weekofyear                            48
# month                                 11
# year                                2018
# weekday                                3
# Name: 318, dtype: object

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
user_df = df[['userId','firstName','lastName','gender','level']]
user_df.head()
# Out:
#   userId firstName lastName gender level
# 0     73     Jacob    Klein      M  paid
# 1     24     Layla  Griffin      F  paid
# 2     24     Layla  Griffin      F  paid
# 3     73     Jacob    Klein      M  paid
# 4     24     Layla  Griffin      F  paid

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
for i, row in user_df.iterrows():
#     print(i)
#     print(row)
    cur.execute(user_table_insert, row)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
for index, row in df.iterrows():

    # get songid and artistid from song and artist tables
    cur.execute(song_select, (row.song, row.artist, row.length))
    results = cur.fetchone()
    
    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None

    # insert songplay record
    songplay_data = (index, pd.to_datetime(row.ts, unit='ms'), int(row.userId), row.level, songid, artistid, row.sessionId, row.location, row.userAgent)
    cur.execute(songplay_table_insert, songplay_data)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
